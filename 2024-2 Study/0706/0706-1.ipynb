# %%
import numpy as np
import pandas as pd

import os
os.listdir("titanic")
# Out:
# ['test.csv', 'train.csv', 'gender_submission.csv']

# %%
df_train = pd.read_csv("titanic/train.csv")

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_train['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df_train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df_train[df_train['Fare'] > 500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df_train[df_train['Fare'] == 0].head()
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 179          180         0       3              Leonard, Mr. Lionel  male
# 263          264         0       1            Harrison, Mr. William  male
# 271          272         1       3     Tornquist, Mr. William Henry  male
# 277          278         0       2      Parkes, Mr. Francis "Frank"  male
# 302          303         0       3  Johnson, Mr. William Cahoone Jr  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 179  36.0      0      0    LINE   0.0   NaN        S
# 263  40.0      0      0  112059   0.0   B94        S
# 271  25.0      0      0    LINE   0.0   NaN        S
# 277   NaN      0      0  239853   0.0   NaN        S
# 302  19.0      0      0    LINE   0.0   NaN        S

# %%
from sklearn.metrics import accuracy_score

# %%
import re
import sklearn

# !pip install xgboost
import xgboost as xb
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.0-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 27.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.9.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.0

# %%
# %matplotlib inline

data = pd.concat([df_train['Fare'], df_train['Embarked']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='Embarked', y='Fare', data=data)

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
percent_data = percent.head(20)
percent_data.plot(kind="bar", figsize=(8, 6), fontsize = 10)
plt.xlabel("")
plt.ylabel("")
plt.title("Total Missing Value (%)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total Missing Value (%)')

# %%
df_train.isnull().sum()/df_train.isnull().count()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
# !pip install missingno
import missingno as msno

missingdata_df = df_train.columns[df_train.isnull().any()].tolist()
msno.heatmap(df_train[missingdata_df], figsize=(8, 6))
plt.title("Correlation with Missing Values", fontsize = 12)
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: seaborn in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from missingno) (0.11.2)
# Requirement already satisfied: matplotlib in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from missingno) (3.5.2)
# Requirement already satisfied: scipy in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from missingno) (1.9.1)
# Requirement already satisfied: numpy in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from missingno) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: pandas>=0.23 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn->missingno) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/a.../opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2
# Text(0.5, 1.0, 'Correlation with Missing Values')

# %%
df_train['hasCabin'] = df_train['Cabin'].isnull().apply(lambda x: 0 if x == True else 1)
df_train['hasAge'] = df_train['Age'].isnull().apply(lambda x: 0 if x == True else 1)

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  hasCabin  hasAge
# 0      0         A/5 21171   7.2500   NaN        S         0       1
# 1      0          PC 17599  71.2833   C85        C         1       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0       1
# 3      0            113803  53.1000  C123        S         1       1
# 4      0            373450   8.0500   NaN        S         0       1

# %%
df_train['Age'].isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Age, dtype: bool

# %%
df_train[df_train['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked  hasCabin  hasAge
# 5       0      0  330877   8.4583   NaN        Q         0       0
# 17      0      0  244373  13.0000   NaN        S         0       0
# 19      0      0    2649   7.2250   NaN        C         0       0
# 26      0      0    2631   7.2250   NaN        C         0       0
# 28      0      0  330959   7.8792   NaN        Q         0       0

# %%
df_train.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# hasCabin        0.019919  0.316912 -0.725541  0.249732 -0.040460  0.036987
# hasAge          0.020167  0.092197 -0.172933       NaN -0.018958  0.124104
#
#                  Fare  hasCabin    hasAge
# PassengerId  0.012658  0.019919  0.020167
# Survived     0.257307  0.316912  0.092197
# Pclass      -0.549500 -0.725541 -0.172933
# Age          0.096067  0.249732       NaN
# SibSp        0.159651 -0.040460 -0.018958
# Parch        0.216225  0.036987  0.124104
# Fare         1.000000  0.482075  0.100707
# hasCabin     0.482075  1.000000  0.144111
# hasAge       0.100707  0.144111  1.000000

# %%
from statsmodels.graphics.mosaicplot import mosaic
mosaic(df_train, ['hasCabin', 'Pclass'],gap=0.02)
plt.show()

# %%
data=pd.concat([df_train['Fare'], df_train['hasCabin']], axis = 1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='hasCabin', y='Fare', data=data)

# %%
df_train[df_train['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  hasCabin  hasAge
# 61   female  38.0      0      0  113572  80.0   B28      NaN         1       1
# 829  female  62.0      0      0  113572  80.0   B28      NaN         1       1

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="Embarked", y="Fare", hue="Pclass", data=df_train, palette="Set3")
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Fare'>
